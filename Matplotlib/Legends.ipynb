# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 20)
y = x * x
z = x + y

# %%
plt.plot(x, y, y, x, label = 'First Example')
plt.legend(loc = 1)
