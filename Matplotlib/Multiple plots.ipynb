# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 20)
y = x * x
z = x + y

# %%
plt.plot(x, y, y, x, label = 'First Example')
plt.legend(loc = 1)

# %%
fig = plt.figure()
x1 = fig.add_axes([0.1,0.1,0.8,0.8])
x1.plot(x,y)
x2 = fig.add_axes([0.3,0.3,0.3,0.3])
x2.plot(x,y)
x3 = fig.add_axes([0.6,0.6,0.1,0.1])
x3.plot(x,y)

# %%
fig, axes = plt.subplots(2,2)
axes[(1,1)].plot(x,y)
axes[(0,1)].plot(y,x)
plt.tight_layout()
