# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 20)
y = x * x
z = x + y

# %%
plt.plot(x,y)

# %%
fig = plt.figure()             #create variable axes graph
axes = fig.add_axes([0.1,0.1,1,1])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,.3,.3])
